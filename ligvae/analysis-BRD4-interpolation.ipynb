# %% [markdown]
# # BRD4 Interpolation in Latent Space

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
from rdkit import Chem
from rdkit import DataStructs
from rdkit.Chem import AllChem
import rdkit.Chem.PandasTools as PandasTools

PandasTools.InstallPandasTools()

# %%
import os

# %% [markdown]
# ### Analysis Variables

# %%
blob="lig_gen"

# %% [markdown]
# ### Helper Functions

# %% [markdown]
# TODO: Extract such functions in a Python module.

# %%
def root_and_prefix(datafile):
    """
    Root directory and prefix.
    """
    dataroot = os.path.dirname(datafile)
    prefix, _ = os.path.splitext(os.path.basename(datafile))
    
    return dataroot, prefix

# %% [markdown]
# ## Variability Factor 1.0

# %% [markdown]
# ### Data

# %%
droot = "data/BRD4/sdf/"

# %%
datafile = "generated/BRD4interpolation_vf1.0_inter.gen_metrics"

# %% [markdown]
# Load generative model metrics (from `*.gen_metrics` file):

# %%
dataroot, prefix = root_and_prefix(datafile)
prefix
# Out:
# 'BRD4interpolation_vf1.0_inter'

# %%
system = prefix.split("_")[0]
system
# Out:
# 'BRD4interpolation'

# %%
with open(f"data/{system}.types", "r") as f:
    inputs = f.readlines()
    
inputs
# Out:
# ['1 0.00 BRD4/pdb/BRD4.pdb BRD4/sdf/ligand-1_min.sdf\n',
#  '1 0.00 BRD4/pdb/BRD4.pdb BRD4/sdf/ligand-10_min.sdf\n',
#  '1 0.00 BRD4/pdb/BRD4.pdb BRD4/sdf/ligand-2_min.sdf\n',
#  '1 0.00 BRD4/pdb/BRD4.pdb BRD4/sdf/ligand-3_min.sdf\n']

# %%
def ligname(line):
    ligfile = line.strip().split()[-1]
    ligname = os.path.splitext(os.path.basename(ligfile))[0]
    return ligname

ligand_pairs = [(ligname(inputs[i]), ligname(inputs[i+1])) for i in range(0, len(inputs), 2)]
ligand_pairs
# Out:
# [('ligand-1_min', 'ligand-10_min'), ('ligand-2_min', 'ligand-3_min')]

# %%
interpolations = {}

# %%
for ligandpair in ligand_pairs:
    molecules = []
    
    lig1, lig2 = ligandpair
    
    # Start molecule
    molecules.append(next(Chem.SDMolSupplier(f"{droot}/{lig1}.sdf")))
    AllChem.Compute2DCoords(molecules[0])
    
    lig1f = f"generated/{prefix}_{lig1}_{blob}_fit_add.sdf"
    suppl1 = Chem.SDMolSupplier(lig1f)
    for mol in suppl1:
        if mol is not None:
            AllChem.Compute2DCoords(mol)
            molecules.append(mol)
            
    lig2f = f"generated/{prefix}_{lig2}_{blob}_fit_add.sdf"
    suppl2 = Chem.SDMolSupplier(lig2f)
    for mol in suppl2:
        if mol is not None:
            AllChem.Compute2DCoords(mol)
            molecules.append(mol)
            
    # End molecule
    molecules.append(next(Chem.SDMolSupplier(f"{droot}/{lig2}.sdf")))
    AllChem.Compute2DCoords(molecules[-1])
            
    interpolations[f"{lig1}/{lig2}"] = molecules

# %%
def tsimilarity(molecules):
    
    fps = [AllChem.GetMorganFingerprintAsBitVect(mol,2,nBits=1024) for mol in molecules]
    
    start_fp = fps[0]
    end_fp = fps[-1]
    
    sim_with_start = []
    sim_with_end = []
    for fp in fps:
        sim_with_start.append(DataStructs.FingerprintSimilarity(fp,start_fp))
        sim_with_end.append(DataStructs.FingerprintSimilarity(fp,end_fp))
        
    return sim_with_start[1:-1], sim_with_end[1:-1]

# %%
def msimilarity(molecules):
    from rdkit.Chem import MACCSkeys
    
    fps = [MACCSkeys.GenMACCSKeys(mol) for mol in molecules]
    
    start_fp = fps[0]
    end_fp = fps[-1]
    
    sim_with_start = []
    sim_with_end = []
    for fp in fps:
        sim_with_start.append(DataStructs.FingerprintSimilarity(fp,start_fp))
        sim_with_end.append(DataStructs.FingerprintSimilarity(fp,end_fp))
        
    return sim_with_start[1:-1], sim_with_end[1:-1]

# %% [markdown]
# ## First Interpolation

# %%
idx = 0 # Interpolation index (first pair, second pair, ...)
key = list(interpolations.keys())[idx]

# %%
key
# Out:
# 'ligand-1_min/ligand-10_min'

# %%
tsim_start, tsim_end = tsimilarity(interpolations[key])

# %%
plt.plot(range(len(tsim_start)), tsim_start,"o-", label="Similatiry to START")
plt.plot(range(len(tsim_end)), tsim_end,"o-", label="Similarity to END")
plt.xlabel("Latent Space Sample")
plt.ylabel("Tanimoto Similatiry")
# Out:
# Text(0, 0.5, 'Tanimoto Similatiry')

# %%
msim_start, msim_end = msimilarity(interpolations[key])

# %%
plt.plot(range(len(tsim_start)), msim_start,"o-", label="Similatiry to START")
plt.plot(range(len(tsim_end)), msim_end,"o-", label="Similarity to END")
plt.xlabel("Latent Space Sample")
plt.ylabel("Tanimoto Similatiry")
plt.title("MACCS")
# Out:
# Text(0.5, 1.0, 'MACCS')

# %%
df = pd.DataFrame().from_dict({"sim_start": tsim_start, "sim_end": tsim_end})
df.head()
# Out:
#    sim_start   sim_end
# 0   0.118644  0.048193
# 1   0.118644  0.048193
# 2   0.118644  0.048193
# 3   0.103448  0.036585
# 4   0.103448  0.036585

# %%
df.index = interpolations[key][1:-1]
df.columns = [interpolations[key][0], interpolations[key][-1]]

# %%
df.style.background_gradient(cmap=sns.cm.rocket, vmin=0, vmax=1)
# Out:
# <style  type="text/css" >
# #T_3964a_row0_col0,#T_3964a_row1_col0,#T_3964a_row2_col0{
#             background-color:  #2d1738;
#             color:  #f1f1f1;
#         }#T_3964a_row0_col1,#T_3964a_row1_col1,#T_3964a_row2_col1,#T_3964a_row5_col1,#T_3964a_row6_col1,#T_3964a_row7_col1,#T_3964a_row12_col0,#T_3964a_row13_col0,#T_3964a_row14_col0,#T_3964a_row18_col0,#T_3964a_row27_col0,#T_3964a_row47_col0{
#             background-color:  #130d25;
#             color:  #f1f1f1;
#         }#T_3964a_row3_col0,#T_3964a_row4_col0,#T_3964a_row9_col1{
#             background-color:  #271534;
#             color:  #f1f1f1;
#         }#T_3964a_row3_col1,#T_3964a_row4_col1,#T_3964a_row24_col0,#T_3964a_row25_col0,#T_3964a_row44_col0,#T_3964a_row45_col0,#T_3964a_row46_col0{
#             background-color:  #0e0b22;
#             color:  #f1f1f1;
#         }#T_3964a_row5_col0,#T_3964a_row6_col0{
#             background-color:  #2e1739;
#             color:  #f1f1f1;
#         }#T_3964a_row7_col0{
#             background-color:  #511e4d;
#             color:  #f1f1f1;
#         }#T_3964a_row8_col0,#T_3964a_row39_col1,#T_3964a_row44_col1{
#             background-color:  #35193e;
#             color:  #f1f1f1;
#         }#T_3964a_row8_col1,#T_3964a_row10_col0,#T_3964a_row17_col0,#T_3964a_row18_col1,#T_3964a_row22_col1{
#             background-color:  #180f29;
#             color:  #f1f1f1;
#         }#T_3964a_row9_col0{
#             background-color:  #561e4f;
#             color:  #f1f1f1;
#         }#T_3964a_row10_col1,#T_3964a_row12_col1,#T_3964a_row13_col1,#T_3964a_row14_col1,#T_3964a_row17_col1{
#             background-color:  #170f28;
#             color:  #f1f1f1;
#         }#T_3964a_row11_col0,#T_3964a_row47_col1{
#             background-color:  #37193f;
#             color:  #f1f1f1;
#         }#T_3964a_row11_col1,#T_3964a_row19_col0,#T_3964a_row20_col0,#T_3964a_row21_col0,#T_3964a_row35_col0{
#             background-color:  #20122e;
#             color:  #f1f1f1;
#         }#T_3964a_row15_col0,#T_3964a_row16_col0,#T_3964a_row26_col0,#T_3964a_row43_col0{
#             background-color:  #1e122d;
#             color:  #f1f1f1;
#         }#T_3964a_row15_col1,#T_3964a_row16_col1,#T_3964a_row30_col0,#T_3964a_row31_col0,#T_3964a_row32_col0{
#             background-color:  #1b112b;
#             color:  #f1f1f1;
#         }#T_3964a_row19_col1,#T_3964a_row20_col1,#T_3964a_row21_col1,#T_3964a_row33_col0{
#             background-color:  #1d112c;
#             color:  #f1f1f1;
#         }#T_3964a_row22_col0,#T_3964a_row23_col0{
#             background-color:  #1a102a;
#             color:  #f1f1f1;
#         }#T_3964a_row23_col1,#T_3964a_row27_col1{
#             background-color:  #211330;
#             color:  #f1f1f1;
#         }#T_3964a_row24_col1,#T_3964a_row34_col0,#T_3964a_row39_col0,#T_3964a_row41_col0{
#             background-color:  #100b23;
#             color:  #f1f1f1;
#         }#T_3964a_row25_col1,#T_3964a_row42_col0{
#             background-color:  #140e26;
#             color:  #f1f1f1;
#         }#T_3964a_row26_col1,#T_3964a_row28_col1{
#             background-color:  #251433;
#             color:  #f1f1f1;
#         }#T_3964a_row28_col0,#T_3964a_row29_col0,#T_3964a_row48_col0,#T_3964a_row49_col0{
#             background-color:  #110c24;
#             color:  #f1f1f1;
#         }#T_3964a_row29_col1,#T_3964a_row33_col1{
#             background-color:  #241432;
#             color:  #f1f1f1;
#         }#T_3964a_row30_col1,#T_3964a_row31_col1,#T_3964a_row32_col1,#T_3964a_row40_col1{
#             background-color:  #2b1637;
#             color:  #f1f1f1;
#         }#T_3964a_row34_col1{
#             background-color:  #221331;
#             color:  #f1f1f1;
#         }#T_3964a_row35_col1{
#             background-color:  #30173a;
#             color:  #f1f1f1;
#         }#T_3964a_row36_col0,#T_3964a_row37_col0,#T_3964a_row38_col0{
#             background-color:  #160e27;
#             color:  #f1f1f1;
#         }#T_3964a_row36_col1,#T_3964a_row37_col1,#T_3964a_row38_col1,#T_3964a_row41_col1,#T_3964a_row48_col1{
#             background-color:  #3a1a41;
#             color:  #f1f1f1;
#         }#T_3964a_row40_col0{
#             background-color:  #06071c;
#             color:  #f1f1f1;
#         }#T_3964a_row42_col1,#T_3964a_row43_col1{
#             background-color:  #281535;
#             color:  #f1f1f1;
#         }#T_3964a_row45_col1,#T_3964a_row46_col1{
#             background-color:  #34193d;
#             color:  #f1f1f1;
#         }#T_3964a_row49_col1{
#             background-color:  #3d1a42;
#             color:  #f1f1f1;
#         }</style><table id="T_3964a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>        <th class="col_heading level0 col1" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3964a_level0_row0" class="row_heading level0 row0" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_3964a_row0_col0" class="data row0 col0" >0.118644</td>
#                         <td id="T_3964a_row0_col1" class="data row0 col1" >0.048193</td>
#             </tr>
#             <tr>
#                         <th id="T_3964a_level0_row1" class="row_heading level0 row1" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_3964a_row1_col0" class="data row1 col0" >0.118644</td>
#                         <td id="T_3964a_row1_col1" class="data row1 col1" >0.048193</td>
#             </tr>
#             <tr>
#                         <th id="T_3964a_level0_row2" class="row_heading level0 row2" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_3964a_row2_col0" class="data row2 col0" >0.118644</td>
#                         <td id="T_3964a_row2_col1" class="data row2 col1" >0.048193</td>
#             </tr>
#             <tr>
#                         <th id="T_3964a_level0_row3" class="row_heading level0 row3" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_3964a_row3_col0" class="data row3 col0" >0.103448</td>
#                         <td id="T_3964a_row3_col1" class="data row3 col1" >0.036585</td>
#             </tr>
#             <tr>
#                         <th id="T_3964a_level0_row4" class="row_heading level0 row4" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_3964a_row4_col0" class="data row4 col0" >0.103448</td>
#                         <td id="T_3964a_row4_col1" class="data row4 col1" >0.036585</td>
#             </tr>
#             <tr>
#                         <th id="T_3964a_level0_row5" class="row_heading level0 row5" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_3964a_row5_col0" class="data row5 col0" >0.122807</td>
#                         <td id="T_3964a_row5_col1" class="data row5 col1" >0.049383</td>
#             </tr>
#             <tr>
#                         <th id="T_3964a_level0_row6" class="row_heading level0 row6" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_3964a_row6_col0" class="data row6 col0" >0.122807</td>
#                         <td id="T_3964a_row6_col1" class="data row6 col1" >0.049383</td>
#             </tr>
#             <tr>
#                         <th id="T_3964a_level0_row7" class="row_heading level0 row7" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_3964a_row7_col0" class="data row7 col0" >0.211538</td>
#                         <td id="T_3964a_row7_col1" class="data row7 col1" >0.050000</td>
#             </tr>
#             <tr>
#                         <th id="T_3964a_level0_row8" class="row_heading level0 row8" ><img data

# %%
sns.heatmap(df.to_numpy().T)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Second Interpolation

# %%
idx = 1 # Interpolation index (first pair, second pair, ...)
key = list(interpolations.keys())[idx]

# %%
key
# Out:
# 'ligand-2_min/ligand-3_min'

# %%
tsim_start, tsim_end = tsimilarity(interpolations[key])

# %%
plt.plot(range(len(tsim_start)), tsim_start,"o-", label="Similatiry to START")
plt.plot(range(len(tsim_end)), tsim_end,"o-", label="Similarity to END")
plt.xlabel("Latent Space Sample")
plt.ylabel("Tanimoto Similatiry")
# Out:
# Text(0, 0.5, 'Tanimoto Similatiry')

# %%
msim_start, msim_end = msimilarity(interpolations[key])

# %%
plt.plot(range(len(tsim_start)), msim_start,"o-", label="Similatiry to START")
plt.plot(range(len(tsim_end)), msim_end,"o-", label="Similarity to END")
plt.xlabel("Latent Space Sample")
plt.ylabel("Tanimoto Similatiry")
plt.title("MACCS")
# Out:
# Text(0.5, 1.0, 'MACCS')

# %%
df = pd.DataFrame().from_dict({"sim_start": tsim_start, "sim_end": tsim_end})
df.head()
# Out:
#    sim_start   sim_end
# 0   0.326531  0.121622
# 1   0.181818  0.121622
# 2   0.106061  0.123457
# 3   0.107692  0.125000
# 4   0.152542  0.088608

# %%
df.index = interpolations[key][1:-1]
df.columns = [interpolations[key][0], interpolations[key][-1]]

# %%
df.style.background_gradient(cmap=sns.cm.rocket, vmin=0, vmax=1)
# Out:
# <style  type="text/css" >
# #T_03781_row0_col0{
#             background-color:  #811e5a;
#             color:  #f1f1f1;
#         }#T_03781_row0_col1,#T_03781_row1_col1,#T_03781_row2_col1,#T_03781_row33_col1{
#             background-color:  #2e1739;
#             color:  #f1f1f1;
#         }#T_03781_row1_col0{
#             background-color:  #451c47;
#             color:  #f1f1f1;
#         }#T_03781_row2_col0,#T_03781_row3_col0,#T_03781_row7_col1,#T_03781_row15_col1,#T_03781_row27_col1,#T_03781_row36_col1{
#             background-color:  #281535;
#             color:  #f1f1f1;
#         }#T_03781_row3_col1{
#             background-color:  #30173a;
#             color:  #f1f1f1;
#         }#T_03781_row4_col0{
#             background-color:  #3a1a41;
#             color:  #f1f1f1;
#         }#T_03781_row4_col1,#T_03781_row5_col0,#T_03781_row6_col0,#T_03781_row13_col1{
#             background-color:  #211330;
#             color:  #f1f1f1;
#         }#T_03781_row5_col1,#T_03781_row42_col1,#T_03781_row43_col1{
#             background-color:  #2a1636;
#             color:  #f1f1f1;
#         }#T_03781_row6_col1,#T_03781_row8_col0,#T_03781_row14_col1,#T_03781_row25_col1{
#             background-color:  #241432;
#             color:  #f1f1f1;
#         }#T_03781_row7_col0,#T_03781_row22_col0{
#             background-color:  #130d25;
#             color:  #f1f1f1;
#         }#T_03781_row8_col1,#T_03781_row9_col1,#T_03781_row28_col1,#T_03781_row29_col1,#T_03781_row30_col1,#T_03781_row40_col1{
#             background-color:  #251433;
#             color:  #f1f1f1;
#         }#T_03781_row9_col0,#T_03781_row18_col1{
#             background-color:  #170f28;
#             color:  #f1f1f1;
#         }#T_03781_row10_col0,#T_03781_row23_col1,#T_03781_row41_col0,#T_03781_row42_col0,#T_03781_row43_col0{
#             background-color:  #140e26;
#             color:  #f1f1f1;
#         }#T_03781_row10_col1,#T_03781_row17_col0,#T_03781_row18_col0,#T_03781_row38_col1,#T_03781_row39_col1{
#             background-color:  #1e122d;
#             color:  #f1f1f1;
#         }#T_03781_row11_col0,#T_03781_row12_col0,#T_03781_row13_col0,#T_03781_row15_col0,#T_03781_row16_col0,#T_03781_row22_col1,#T_03781_row33_col0,#T_03781_row35_col1{
#             background-color:  #180f29;
#             color:  #f1f1f1;
#         }#T_03781_row11_col1,#T_03781_row20_col1{
#             background-color:  #221331;
#             color:  #f1f1f1;
#         }#T_03781_row12_col1,#T_03781_row21_col1,#T_03781_row34_col1,#T_03781_row37_col1{
#             background-color:  #271534;
#             color:  #f1f1f1;
#         }#T_03781_row14_col0,#T_03781_row24_col1,#T_03781_row31_col0,#T_03781_row35_col0{
#             background-color:  #1a102a;
#             color:  #f1f1f1;
#         }#T_03781_row16_col1{
#             background-color:  #33183c;
#             color:  #f1f1f1;
#         }#T_03781_row17_col1,#T_03781_row19_col0{
#             background-color:  #1d112c;
#             color:  #f1f1f1;
#         }#T_03781_row19_col1,#T_03781_row32_col0{
#             background-color:  #1b112b;
#             color:  #f1f1f1;
#         }#T_03781_row20_col0,#T_03781_row25_col0,#T_03781_row36_col0{
#             background-color:  #160e27;
#             color:  #f1f1f1;
#         }#T_03781_row21_col0,#T_03781_row34_col0{
#             background-color:  #20122e;
#             color:  #f1f1f1;
#         }#T_03781_row23_col0,#T_03781_row24_col0{
#             background-color:  #0d0a21;
#             color:  #f1f1f1;
#         }#T_03781_row26_col0,#T_03781_row27_col0,#T_03781_row28_col0,#T_03781_row29_col0,#T_03781_row38_col0,#T_03781_row39_col0{
#             background-color:  #0b0920;
#             color:  #f1f1f1;
#         }#T_03781_row26_col1{
#             background-color:  #2b1637;
#             color:  #f1f1f1;
#         }#T_03781_row30_col0{
#             background-color:  #110c24;
#             color:  #f1f1f1;
#         }#T_03781_row31_col1{
#             background-color:  #37193f;
#             color:  #f1f1f1;
#         }#T_03781_row32_col1{
#             background-color:  #2d1738;
#             color:  #f1f1f1;
#         }#T_03781_row37_col0{
#             background-color:  #06071c;
#             color:  #f1f1f1;
#         }#T_03781_row40_col0{
#             background-color:  #0e0b22;
#             color:  #f1f1f1;
#         }#T_03781_row41_col1{
#             background-color:  #381a40;
#             color:  #f1f1f1;
#         }</style><table id="T_03781_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>        <th class="col_heading level0 col1" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_03781_level0_row0" class="row_heading level0 row0" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_03781_row0_col0" class="data row0 col0" >0.326531</td>
#                         <td id="T_03781_row0_col1" class="data row0 col1" >0.121622</td>
#             </tr>
#             <tr>
#                         <th id="T_03781_level0_row1" class="row_heading level0 row1" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_03781_row1_col0" class="data row1 col0" >0.181818</td>
#                         <td id="T_03781_row1_col1" class="data row1 col1" >0.121622</td>
#             </tr>
#             <tr>
#                         <th id="T_03781_level0_row2" class="row_heading level0 row2" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_03781_row2_col0" class="data row2 col0" >0.106061</td>
#                         <td id="T_03781_row2_col1" class="data row2 col1" >0.123457</td>
#             </tr>
#             <tr>
#                         <th id="T_03781_level0_row3" class="row_heading level0 row3" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_03781_row3_col0" class="data row3 col0" >0.107692</td>
#                         <td id="T_03781_row3_col1" class="data row3 col1" >0.125000</td>
#             </tr>
#             <tr>
#                         <th id="T_03781_level0_row4" class="row_heading level0 row4" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_03781_row4_col0" class="data row4 col0" >0.152542</td>
#                         <td id="T_03781_row4_col1" class="data row4 col1" >0.088608</td>
#             </tr>
#             <tr>
#                         <th id="T_03781_level0_row5" class="row_heading level0 row5" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_03781_row5_col0" class="data row5 col0" >0.089552</td>
#                         <td id="T_03781_row5_col1" class="data row5 col1" >0.109756</td>
#             </tr>
#             <tr>
#                         <th id="T_03781_level0_row6" class="row_heading level0 row6" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_03781_row6_col0" class="data row6 col0" >0.088235</td>
#                         <td id="T_03781_row6_col1" class="data row6 col1" >0.095238</td>
#             </tr>
#             <tr>
#                         <th id="T_03781_level0_row7" class="row_heading level0 row7" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_03781_row7_col0" class="data row7 col0" >0.048387</td>
#                         <td id="T_03781_row7_col1" class="data row7 col1" >0.106667</td>
#             </tr>
#             <tr>
#                         <th id="T_03781_level0_row8" class="row_heading level0 row8" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_03781_row8_col0" class="data row8 col0" >0.095238</t

# %%
sns.heatmap(df.to_numpy().T)
# Out:
# <AxesSubplot:>
