# %% [markdown]
# # CDK2 Interpolation in Latent Space

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
from rdkit import Chem
from rdkit import DataStructs
from rdkit.Chem import AllChem
import rdkit.Chem.PandasTools as PandasTools

PandasTools.InstallPandasTools()

# %%
import os

# %% [markdown]
# ### Analysis Variables

# %%
blob="lig_gen"

# %% [markdown]
# ### Helper Functions

# %% [markdown]
# TODO: Extract such functions in a Python module.

# %%
def root_and_prefix(datafile):
    """
    Root directory and prefix.
    """
    dataroot = os.path.dirname(datafile)
    prefix, _ = os.path.splitext(os.path.basename(datafile))
    
    return dataroot, prefix

# %% [markdown]
# ## Variability Factor 1.0

# %% [markdown]
# ### Data

# %%
droot = "data/CDK2/data/"

# %%
datafile = "generated/CDK2liginterpolation_vf1.0_inter.gen_metrics"

# %% [markdown]
# Load generative model metrics (from `*.gen_metrics` file):

# %%
dataroot, prefix = root_and_prefix(datafile)
prefix
# Out:
# 'CDK2liginterpolation_vf1.0_inter'

# %%
system = prefix.split("_")[0]
system
# Out:
# 'CDK2liginterpolation'

# %%
with open(f"data/{system}.types", "r") as f:
    inputs = f.readlines()
    
inputs
# Out:
# ['1 0.00 CDK2/data/4EK4.pdb CDK2/data/4ek4_B_1CK_min.sdf\n',
#  '1 0.00 CDK2/data/4FKJ.pdb CDK2/data/4fkj_B_11K_min.sdf\n',
#  '1 0.00 CDK2/data/4FKP.pdb CDK2/data/4fkp_B_LS5_min.sdf\n',
#  '1 0.00 CDK2/data/4FKW.pdb CDK2/data/4fkw_B_62K_min.sdf\n']

# %%
def ligname(line):
    ligfile = line.strip().split()[-1]
    ligname = os.path.splitext(os.path.basename(ligfile))[0]
    return ligname

ligand_pairs = [(ligname(inputs[i]), ligname(inputs[i+1])) for i in range(0, len(inputs), 2)]
ligand_pairs
# Out:
# [('4ek4_B_1CK_min', '4fkj_B_11K_min'), ('4fkp_B_LS5_min', '4fkw_B_62K_min')]

# %%
interpolations = {}

# %%
for ligandpair in ligand_pairs:
    molecules = []
    
    lig1, lig2 = ligandpair
    
    # Start molecule
    molecules.append(next(Chem.SDMolSupplier(f"{droot}/{lig1}.sdf")))
    AllChem.Compute2DCoords(molecules[0])
    
    lig1f = f"generated/{prefix}_{lig1}_{blob}_fit_add.sdf"
    suppl1 = Chem.SDMolSupplier(lig1f)
    for mol in suppl1:
        if mol is not None:
            AllChem.Compute2DCoords(mol)
            molecules.append(mol)
            
    lig2f = f"generated/{prefix}_{lig2}_{blob}_fit_add.sdf"
    suppl2 = Chem.SDMolSupplier(lig2f)
    for mol in suppl2:
        if mol is not None:
            AllChem.Compute2DCoords(mol)
            molecules.append(mol)
            
    # End molecule
    molecules.append(next(Chem.SDMolSupplier(f"{droot}/{lig2}.sdf")))
    AllChem.Compute2DCoords(molecules[-1])
            
    interpolations[f"{lig1}/{lig2}"] = molecules
# Out:
# RDKit ERROR: [16:52:37] Explicit valence for atom # 0 C, 5, is greater than permitted
# RDKit ERROR: [16:52:37] ERROR: Could not sanitize molecule ending on line 968
# RDKit ERROR: [16:52:37] ERROR: Explicit valence for atom # 0 C, 5, is greater than permitted
# RDKit ERROR: [16:52:37] Explicit valence for atom # 1 C, 5, is greater than permitted
# RDKit ERROR: [16:52:37] ERROR: Could not sanitize molecule ending on line 1221
# RDKit ERROR: [16:52:37] ERROR: Explicit valence for atom # 1 C, 5, is greater than permitted
# RDKit ERROR: [16:52:37] Explicit valence for atom # 1 C, 5, is greater than permitted
# RDKit ERROR: [16:52:37] ERROR: Could not sanitize molecule ending on line 1271

# %%
def tsimilarity(molecules):
    
    fps = [AllChem.GetMorganFingerprintAsBitVect(mol,2,nBits=1024) for mol in molecules]
    
    start_fp = fps[0]
    end_fp = fps[-1]
    
    sim_with_start = []
    sim_with_end = []
    for fp in fps:
        sim_with_start.append(DataStructs.FingerprintSimilarity(fp,start_fp))
        sim_with_end.append(DataStructs.FingerprintSimilarity(fp,end_fp))
        
    return sim_with_start[1:-1], sim_with_end[1:-1]

# %%
def msimilarity(molecules):
    from rdkit.Chem import MACCSkeys
    
    fps = [MACCSkeys.GenMACCSKeys(mol) for mol in molecules]
    
    start_fp = fps[0]
    end_fp = fps[-1]
    
    sim_with_start = []
    sim_with_end = []
    for fp in fps:
        sim_with_start.append(DataStructs.FingerprintSimilarity(fp,start_fp))
        sim_with_end.append(DataStructs.FingerprintSimilarity(fp,end_fp))
        
    return sim_with_start[1:-1], sim_with_end[1:-1]

# %% [markdown]
# ## First Interpolation

# %%
idx = 0 # Interpolation index (first pair, second pair, ...)
key = list(interpolations.keys())[idx]

# %%
key
# Out:
# '4ek4_B_1CK_min/4fkj_B_11K_min'

# %%
tsim_start, tsim_end = tsimilarity(interpolations[key])

# %%
plt.plot(range(len(tsim_start)), tsim_start,"o-", label="Similatiry to START")
plt.plot(range(len(tsim_end)), tsim_end,"o-", label="Similarity to END")
plt.xlabel("Latent Space Sample")
plt.ylabel("Tanimoto Similatiry")
# Out:
# Text(0, 0.5, 'Tanimoto Similatiry')

# %%
msim_start, msim_end = msimilarity(interpolations[key])

# %%
plt.plot(range(len(tsim_start)), msim_start,"o-", label="Similatiry to START")
plt.plot(range(len(tsim_end)), msim_end,"o-", label="Similarity to END")
plt.xlabel("Latent Space Sample")
plt.ylabel("Tanimoto Similatiry")
plt.title("MACCS")
# Out:
# Text(0.5, 1.0, 'MACCS')

# %%
df = pd.DataFrame().from_dict({"sim_start": tsim_start, "sim_end": tsim_end})
df.head()
# Out:
#    sim_start   sim_end
# 0   0.109375  0.144737
# 1   0.093750  0.116883
# 2   0.129032  0.116883
# 3   0.103448  0.111111
# 4   0.103448  0.111111

# %%
df.index = interpolations[key][1:-1]
df.columns = [interpolations[key][0], interpolations[key][-1]]

# %%
df.style.background_gradient(cmap=sns.cm.rocket, vmin=0, vmax=1)
# Out:
# <style  type="text/css" >
# #T_37e96_row0_col0,#T_37e96_row3_col1,#T_37e96_row4_col1{
#             background-color:  #2a1636;
#             color:  #f1f1f1;
#         }#T_37e96_row0_col1,#T_37e96_row41_col0{
#             background-color:  #37193f;
#             color:  #f1f1f1;
#         }#T_37e96_row1_col0,#T_37e96_row47_col0{
#             background-color:  #241432;
#             color:  #f1f1f1;
#         }#T_37e96_row1_col1,#T_37e96_row2_col1{
#             background-color:  #2b1637;
#             color:  #f1f1f1;
#         }#T_37e96_row2_col0{
#             background-color:  #31183b;
#             color:  #f1f1f1;
#         }#T_37e96_row3_col0,#T_37e96_row4_col0,#T_37e96_row5_col0,#T_37e96_row6_col0,#T_37e96_row7_col0,#T_37e96_row8_col0{
#             background-color:  #271534;
#             color:  #f1f1f1;
#         }#T_37e96_row5_col1,#T_37e96_row10_col0,#T_37e96_row11_col1,#T_37e96_row12_col1,#T_37e96_row13_col1,#T_37e96_row14_col1,#T_37e96_row34_col1{
#             background-color:  #20122e;
#             color:  #f1f1f1;
#         }#T_37e96_row6_col1,#T_37e96_row7_col1,#T_37e96_row8_col1{
#             background-color:  #1e122d;
#             color:  #f1f1f1;
#         }#T_37e96_row9_col0{
#             background-color:  #1a102a;
#             color:  #f1f1f1;
#         }#T_37e96_row9_col1,#T_37e96_row11_col0,#T_37e96_row12_col0,#T_37e96_row13_col0,#T_37e96_row27_col1{
#             background-color:  #140e26;
#             color:  #f1f1f1;
#         }#T_37e96_row10_col1,#T_37e96_row21_col0,#T_37e96_row31_col0,#T_37e96_row37_col0,#T_37e96_row38_col0,#T_37e96_row39_col0{
#             background-color:  #180f29;
#             color:  #f1f1f1;
#         }#T_37e96_row14_col0,#T_37e96_row15_col0,#T_37e96_row17_col1,#T_37e96_row28_col0,#T_37e96_row42_col0,#T_37e96_row45_col0{
#             background-color:  #211330;
#             color:  #f1f1f1;
#         }#T_37e96_row15_col1,#T_37e96_row39_col1{
#             background-color:  #251433;
#             color:  #f1f1f1;
#         }#T_37e96_row16_col0,#T_37e96_row25_col0{
#             background-color:  #0e0b22;
#             color:  #f1f1f1;
#         }#T_37e96_row16_col1,#T_37e96_row23_col1,#T_37e96_row25_col1{
#             background-color:  #0b0920;
#             color:  #f1f1f1;
#         }#T_37e96_row17_col0,#T_37e96_row18_col1,#T_37e96_row24_col1,#T_37e96_row33_col0{
#             background-color:  #160e27;
#             color:  #f1f1f1;
#         }#T_37e96_row18_col0,#T_37e96_row37_col1,#T_37e96_row38_col1{
#             background-color:  #1d112c;
#             color:  #f1f1f1;
#         }#T_37e96_row19_col0,#T_37e96_row20_col0,#T_37e96_row22_col0,#T_37e96_row26_col1,#T_37e96_row32_col0,#T_37e96_row35_col0,#T_37e96_row36_col0{
#             background-color:  #100b23;
#             color:  #f1f1f1;
#         }#T_37e96_row19_col1,#T_37e96_row20_col1,#T_37e96_row22_col1{
#             background-color:  #110c24;
#             color:  #f1f1f1;
#         }#T_37e96_row21_col1,#T_37e96_row32_col1,#T_37e96_row35_col1,#T_37e96_row36_col1,#T_37e96_row46_col0{
#             background-color:  #130d25;
#             color:  #f1f1f1;
#         }#T_37e96_row23_col0,#T_37e96_row26_col0,#T_37e96_row27_col0{
#             background-color:  #0d0a21;
#             color:  #f1f1f1;
#         }#T_37e96_row24_col0{
#             background-color:  #07071d;
#             color:  #f1f1f1;
#         }#T_37e96_row28_col1{
#             background-color:  #34193d;
#             color:  #f1f1f1;
#         }#T_37e96_row29_col0,#T_37e96_row31_col1,#T_37e96_row43_col0,#T_37e96_row44_col0{
#             background-color:  #221331;
#             color:  #f1f1f1;
#         }#T_37e96_row29_col1,#T_37e96_row30_col1{
#             background-color:  #1b112b;
#             color:  #f1f1f1;
#         }#T_37e96_row30_col0,#T_37e96_row33_col1{
#             background-color:  #170f28;
#             color:  #f1f1f1;
#         }#T_37e96_row34_col0{
#             background-color:  #281535;
#             color:  #f1f1f1;
#         }#T_37e96_row40_col0{
#             background-color:  #30173a;
#             color:  #f1f1f1;
#         }#T_37e96_row40_col1{
#             background-color:  #5e1f52;
#             color:  #f1f1f1;
#         }#T_37e96_row41_col1{
#             background-color:  #4e1d4b;
#             color:  #f1f1f1;
#         }#T_37e96_row42_col1{
#             background-color:  #381a40;
#             color:  #f1f1f1;
#         }#T_37e96_row43_col1{
#             background-color:  #3a1a41;
#             color:  #f1f1f1;
#         }#T_37e96_row44_col1{
#             background-color:  #481c48;
#             color:  #f1f1f1;
#         }#T_37e96_row45_col1,#T_37e96_row46_col1{
#             background-color:  #35193e;
#             color:  #f1f1f1;
#         }#T_37e96_row47_col1{
#             background-color:  #431c46;
#             color:  #f1f1f1;
#         }</style><table id="T_37e96_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>        <th class="col_heading level0 col1" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_37e96_level0_row0" class="row_heading level0 row0" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_37e96_row0_col0" class="data row0 col0" >0.109375</td>
#                         <td id="T_37e96_row0_col1" class="data row0 col1" >0.144737</td>
#             </tr>
#             <tr>
#                         <th id="T_37e96_level0_row1" class="row_heading level0 row1" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_37e96_row1_col0" class="data row1 col0" >0.093750</td>
#                         <td id="T_37e96_row1_col1" class="data row1 col1" >0.116883</td>
#             </tr>
#             <tr>
#                         <th id="T_37e96_level0_row2" class="row_heading level0 row2" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_37e96_row2_col0" class="data row2 col0" >0.129032</td>
#                         <td id="T_37e96_row2_col1" class="data row2 col1" >0.116883</td>
#             </tr>
#             <tr>
#                         <th id="T_37e96_level0_row3" class="row_heading level0 row3" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_37e96_row3_col0" class="data row3 col0" >0.103448</td>
#                         <td id="T_37e96_row3_col1" class="data row3 col1" >0.111111</td>
#             </tr>
#             <tr>
#                         <th id="T_37e96_level0_row4" class="row_heading level0 row4" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_37e96_row4_col0" class="data row4 col0" >0.103448</td>
#                         <td id="T_37e96_row4_col1" class="data row4 col1" >0.111111</td>
#             </tr>
#             <tr>
#                         <th id="T_37e96_level0_row5" class="row_heading level0 row5" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_37e96_row5_col0" class="data row5 col0" >0.105263</td>
#                         <td id="T_37e96_row5_col1" class="data row5 col1" >0.082192</td>
#             </tr>
#             <tr>
#                         <th id="T_37e96_level0_row6" class="row_heading level0 row6" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_37e96_row6_col0" class="data row6 col0" >0.103448</td>
#                         <td id="T_37e96_row6_col1" class="data row6 col1" >0.081081</td>
#             </tr>
#             <tr>
#                         <th id="T_37e96_level0_row7" class="row_heading level0 row7" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_37e96_row7_col0" class="data row7 col0

# %%
sns.heatmap(df.to_numpy().T)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Second Interpolation

# %%
idx = 1 # Interpolation index (first pair, second pair, ...)
key = list(interpolations.keys())[idx]

# %%
key
# Out:
# '4fkp_B_LS5_min/4fkw_B_62K_min'

# %%
tsim_start, tsim_end = tsimilarity(interpolations[key])

# %%
plt.plot(range(len(tsim_start)), tsim_start,"o-", label="Similatiry to START")
plt.plot(range(len(tsim_end)), tsim_end,"o-", label="Similarity to END")
plt.xlabel("Latent Space Sample")
plt.ylabel("Tanimoto Similatiry")
# Out:
# Text(0, 0.5, 'Tanimoto Similatiry')

# %%
msim_start, msim_end = msimilarity(interpolations[key])

# %%
plt.plot(range(len(tsim_start)), msim_start,"o-", label="Similatiry to START")
plt.plot(range(len(tsim_end)), msim_end,"o-", label="Similarity to END")
plt.xlabel("Latent Space Sample")
plt.ylabel("Tanimoto Similatiry")
plt.title("MACCS")
# Out:
# Text(0.5, 1.0, 'MACCS')

# %%
df = pd.DataFrame().from_dict({"sim_start": tsim_start, "sim_end": tsim_end})
df.head()
# Out:
#    sim_start   sim_end
# 0   0.117647  0.106383
# 1   0.103448  0.093750
# 2   0.103448  0.093750
# 3   0.119048  0.107527
# 4   0.119048  0.107527

# %%
df.index = interpolations[key][1:-1]
df.columns = [interpolations[key][0], interpolations[key][-1]]

# %%
df.style.background_gradient(cmap=sns.cm.rocket, vmin=0, vmax=1)
# Out:
# <style  type="text/css" >
# #T_ac637_row0_col0,#T_ac637_row3_col0,#T_ac637_row4_col0,#T_ac637_row5_col0,#T_ac637_row12_col0,#T_ac637_row12_col1,#T_ac637_row23_col1,#T_ac637_row24_col0,#T_ac637_row24_col1,#T_ac637_row38_col0,#T_ac637_row45_col0{
#             background-color:  #2d1738;
#             color:  #f1f1f1;
#         }#T_ac637_row0_col1,#T_ac637_row3_col1,#T_ac637_row4_col1,#T_ac637_row5_col1,#T_ac637_row23_col0{
#             background-color:  #281535;
#             color:  #f1f1f1;
#         }#T_ac637_row1_col0,#T_ac637_row2_col0{
#             background-color:  #271534;
#             color:  #f1f1f1;
#         }#T_ac637_row1_col1,#T_ac637_row2_col1,#T_ac637_row9_col0,#T_ac637_row25_col1,#T_ac637_row29_col1,#T_ac637_row31_col0,#T_ac637_row37_col0,#T_ac637_row39_col0,#T_ac637_row40_col1,#T_ac637_row41_col1,#T_ac637_row44_col0{
#             background-color:  #241432;
#             color:  #f1f1f1;
#         }#T_ac637_row6_col0{
#             background-color:  #34193d;
#             color:  #f1f1f1;
#         }#T_ac637_row6_col1,#T_ac637_row7_col1,#T_ac637_row8_col1,#T_ac637_row11_col1,#T_ac637_row43_col0{
#             background-color:  #33183c;
#             color:  #f1f1f1;
#         }#T_ac637_row7_col0,#T_ac637_row8_col0,#T_ac637_row17_col0,#T_ac637_row18_col0{
#             background-color:  #2e1739;
#             color:  #f1f1f1;
#         }#T_ac637_row9_col1,#T_ac637_row10_col0,#T_ac637_row22_col0,#T_ac637_row22_col1,#T_ac637_row30_col0,#T_ac637_row33_col0,#T_ac637_row33_col1,#T_ac637_row34_col0,#T_ac637_row34_col1{
#             background-color:  #251433;
#             color:  #f1f1f1;
#         }#T_ac637_row10_col1,#T_ac637_row29_col0,#T_ac637_row36_col1,#T_ac637_row40_col0,#T_ac637_row41_col0,#T_ac637_row42_col1{
#             background-color:  #1e122d;
#             color:  #f1f1f1;
#         }#T_ac637_row11_col0,#T_ac637_row37_col1,#T_ac637_row39_col1{
#             background-color:  #2a1636;
#             color:  #f1f1f1;
#         }#T_ac637_row13_col0{
#             background-color:  #30173a;
#             color:  #f1f1f1;
#         }#T_ac637_row13_col1,#T_ac637_row15_col0,#T_ac637_row16_col0{
#             background-color:  #381a40;
#             color:  #f1f1f1;
#         }#T_ac637_row14_col0,#T_ac637_row21_col1,#T_ac637_row38_col1,#T_ac637_row44_col1,#T_ac637_row46_col0{
#             background-color:  #31183b;
#             color:  #f1f1f1;
#         }#T_ac637_row14_col1,#T_ac637_row19_col0,#T_ac637_row19_col1,#T_ac637_row46_col1{
#             background-color:  #35193e;
#             color:  #f1f1f1;
#         }#T_ac637_row15_col1,#T_ac637_row16_col1,#T_ac637_row17_col1,#T_ac637_row18_col1{
#             background-color:  #3d1a42;
#             color:  #f1f1f1;
#         }#T_ac637_row20_col0{
#             background-color:  #37193f;
#             color:  #f1f1f1;
#         }#T_ac637_row20_col1,#T_ac637_row21_col0,#T_ac637_row45_col1{
#             background-color:  #3c1a42;
#             color:  #f1f1f1;
#         }#T_ac637_row25_col0,#T_ac637_row27_col0,#T_ac637_row28_col0{
#             background-color:  #1a102a;
#             color:  #f1f1f1;
#         }#T_ac637_row26_col0,#T_ac637_row31_col1,#T_ac637_row42_col0{
#             background-color:  #1d112c;
#             color:  #f1f1f1;
#         }#T_ac637_row26_col1,#T_ac637_row30_col1{
#             background-color:  #221331;
#             color:  #f1f1f1;
#         }#T_ac637_row27_col1,#T_ac637_row28_col1{
#             background-color:  #1b112b;
#             color:  #f1f1f1;
#         }#T_ac637_row32_col0,#T_ac637_row35_col1{
#             background-color:  #211330;
#             color:  #f1f1f1;
#         }#T_ac637_row32_col1{
#             background-color:  #2b1637;
#             color:  #f1f1f1;
#         }#T_ac637_row35_col0{
#             background-color:  #180f29;
#             color:  #f1f1f1;
#         }#T_ac637_row36_col0{
#             background-color:  #140e26;
#             color:  #f1f1f1;
#         }#T_ac637_row43_col1{
#             background-color:  #451c47;
#             color:  #f1f1f1;
#         }</style><table id="T_ac637_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>        <th class="col_heading level0 col1" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ac637_level0_row0" class="row_heading level0 row0" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_ac637_row0_col0" class="data row0 col0" >0.117647</td>
#                         <td id="T_ac637_row0_col1" class="data row0 col1" >0.106383</td>
#             </tr>
#             <tr>
#                         <th id="T_ac637_level0_row1" class="row_heading level0 row1" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_ac637_row1_col0" class="data row1 col0" >0.103448</td>
#                         <td id="T_ac637_row1_col1" class="data row1 col1" >0.093750</td>
#             </tr>
#             <tr>
#                         <th id="T_ac637_level0_row2" class="row_heading level0 row2" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_ac637_row2_col0" class="data row2 col0" >0.103448</td>
#                         <td id="T_ac637_row2_col1" class="data row2 col1" >0.093750</td>
#             </tr>
#             <tr>
#                         <th id="T_ac637_level0_row3" class="row_heading level0 row3" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_ac637_row3_col0" class="data row3 col0" >0.119048</td>
#                         <td id="T_ac637_row3_col1" class="data row3 col1" >0.107527</td>
#             </tr>
#             <tr>
#                         <th id="T_ac637_level0_row4" class="row_heading level0 row4" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_ac637_row4_col0" class="data row4 col0" >0.119048</td>
#                         <td id="T_ac637_row4_col1" class="data row4 col1" >0.107527</td>
#             </tr>
#             <tr>
#                         <th id="T_ac637_level0_row5" class="row_heading level0 row5" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_ac637_row5_col0" class="data row5 col0" >0.119048</td>
#                         <td id="T_ac637_row5_col1" class="data row5 col1" >0.107527</td>
#             </tr>
#             <tr>
#                         <th id="T_ac637_level0_row6" class="row_heading level0 row6" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_ac637_row6_col0" class="data row6 col0" >0.137500</td>
#                         <td id="T_ac637_row6_col1" class="data row6 col1" >0.136364</td>
#             </tr>
#             <tr>
#                         <th id="T_ac637_level0_row7" class="row_heading level0 row7" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_ac637_row7_col0" class="data row7 col0" >0.123457</td>
#                         <td id="T_ac637_row7_col1" class="data row7 col1" >0.136364</td>
#             </tr>
#             <tr>
#                         <th id="T_ac637_level0_row8" class="row_heading level0 row8" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_ac637_row8_col0" class="data row8 col0" >0.123457</td>
#                         <td id="T_ac637_row8_col1" class="data row8 col1" >0.136364</td>
#             </tr>
#             <tr>
#                         <th id="T_ac637_level0_row9" class="row_heading level0 row9" ><img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/></th>
#                         <td id="T_ac637_row9_col0" class=

# %%
sns.heatmap(df.to_numpy().T)
# Out:
# <AxesSubplot:>
