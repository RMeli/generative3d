# %% [markdown]
# # Analysis of RMSD change between generated and minimised structures

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
from rdkit import Chem
import rdkit.Chem.PandasTools as PandasTools

PandasTools.InstallPandasTools()

# %%
import os

# %% [markdown]
# ### Analysis Variables

# %%
blob="lig_gen"

# %% [markdown]
# Maximum RMSD threshold used for filtering molecules with low RMSD between generated and minimised structure:

# %%
maxRMSD = 1.0

# %% [markdown]
# Minimum QED threshold used for filtering:

# %%
minQED = 0.7

# %% [markdown]
# ### Helper Functions

# %% [markdown]
# TODO: Extract such functions in a Python module.

# %%
def root_and_prefix(datafile):
    """
    Root directory and prefix.
    """
    dataroot = os.path.dirname(datafile)
    prefix, _ = os.path.splitext(os.path.basename(datafile))
    
    return dataroot, prefix

# %%
def load_rmsd(dataroot, prefix, df):
    """
    Load ligand RMSD CSV files and add RMSD to DataFrame
    """
    ligands = df["lig_name"].unique()

    # Load RMSDs
    for ligand in ligands:
        fname = os.path.join(dataroot, prefix + "_" + ligand + f"_{blob}_RMSDmin.csv")
        df_rmsd = pd.read_csv(fname)
    
        # Assign ligand RMSD to general dataset
        # Assumes sample indices are in the same order (but indices might be missing from RMSD dataframe)
        df.loc[(df["sample_idx"].isin(df_rmsd["sample"])) & (df["lig_name"] == ligand), "rmsd"] =  df_rmsd["rmsd"].to_numpy()

    # Drop all samples for which the RMSD between generated and minimised structures 
    # could not be computed (reconstruction failed):
    nall = len(df)
    df.dropna(subset=["rmsd"], inplace=True)
    
    print(f"Successfully reconstructed molecules: {len(df) / nall * 100:.2f}%")

# %%
def rmsd_statistics(df, mRMSD):
    rmsd = df["rmsd"].to_numpy()
        
    print(f"Average RMSD: {np.mean(rmsd)}")
    print(f"Median RMSD: {np.median(rmsd)}")
    print(f"Percentage of low-RMSD samples: {np.logical_and(rmsd < mRMSD, rmsd > 0.05).sum() / len(rmsd)  * 100}%")
    #print(f"Percentage of unique molecules: {len(df[f'{blob}_fit_add_SMILES'].unique()) / nall * 100}%")

# %%
def filter(df, mRMSD, mQED):
    # Some systems have 0.0 RMSD
    df_lowrmsd = df[(df.rmsd < mRMSD) & (df.rmsd > 0.05)].copy()
    
    # Sort by RMSD, so that fropping duplicates will retain lowest RMSD
    df_lowrmsd.sort_values(by="rmsd", ascending=True, inplace=True)
    df_lowrmsd = df_lowrmsd.drop_duplicates(subset=[f"{blob}_fit_add_SMILES"], keep="first")
    
    # Add RDKit molecule
    PandasTools.AddMoleculeColumnToFrame(df_lowrmsd,f"{blob}_fit_add_SMILES", f"mol_{blob}")
    
    return df_lowrmsd[df_lowrmsd[f"{blob}_fit_add_QED"] > mQED]

# %% [markdown]
# ## Variability Factor 0.5

# %% [markdown]
# ### Data

# %%
datafile = "generated/BRD4_vf0.5_big.gen_metrics"

# %% [markdown]
# Load generative model metrics (from `*.gen_metrics` file):

# %%
dataroot, prefix = root_and_prefix(datafile)
prefix
# Out:
# 'BRD4_vf0.5_big'

# %%
df = pd.read_csv(datafile, sep=" ")
df.head()
# Out:
#        lig_name  sample_idx   lig_norm  lig_variance  lig_gen_norm  \
# 0  ligand-1_min           0  32.281212           NaN     31.334364
# 1  ligand-1_min           1  32.281212           NaN     31.078058
# 2  ligand-1_min           2  32.281212           NaN     30.803549
# 3  ligand-1_min           3  32.281212           NaN     31.119583
# 4  ligand-1_min           4  32.281212           NaN     30.341003
#
#    lig_gen_variance  lig_gen_L2_loss  lig_gen_L1_loss  lig_latent_norm  \
# 0               NaN        20.829268       643.677612        21.236727
# 1               NaN        19.240891       643.663696        20.929674
# 2               NaN        15.925332       607.547302        20.875921
# 3               NaN        23.214975       672.587463        21.000568
# 4               NaN        18.217674       617.264587        21.052877
#
#    lig_latent_variance  ...  lig_gen_fit_add_E  lig_gen_fit_add_min_E  \
# 0                  NaN  ...        3250.771408             592.241163
# 1                  NaN  ...       13125.685102             217.109396
# 2                  NaN  ...        2803.113951             593.242775
# 3                  NaN  ...                NaN                    NaN
# 4                  NaN  ...       24383.449395             367.812914
#
#    lig_gen_fit_add_dE_min  lig_gen_fit_add_min_error  \
# 0            -2658.530245                        NaN
# 1           -12908.575706                        NaN
# 2            -2209.871176                        NaN
# 3                     NaN                        NaN
# 4           -24015.636481                        NaN
#
#    lig_gen_fit_add_min_time  lig_gen_fit_add_RMSD_min  lig_gen_fit_add_dE_ref  \
# 0                  0.011658                  1.135250             3177.180971
# 1                  0.013435                  0.665214            13052.094664
# 2                  0.015571                  1.130002             2729.523513
# 3                  0.001198                       NaN                     NaN
# 4                  0.017397                  1.415420            24309.858957
#
#    lig_gen_fit_add_min_dE_ref  lig_gen_fit_add_RMSD_ref  \
# 0                  518.650725                       NaN
# 1                  143.518958                       NaN
# 2                  519.652337                       NaN
# 3                         NaN                       NaN
# 4                  294.222476                       NaN
#
#    lig_gen_fit_add_min_RMSD_ref
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 125 columns]

# %% [markdown]
# Available metrics:

# %%
print([c for c in df.columns])
# Out:
# ['lig_name', 'sample_idx', 'lig_norm', 'lig_variance', 'lig_gen_norm', 'lig_gen_variance', 'lig_gen_L2_loss', 'lig_gen_L1_loss', 'lig_latent_norm', 'lig_latent_variance', 'lig_fit_norm', 'lig_fit_variance', 'lig_fit_L2_loss', 'lig_fit_L1_loss', 'lig_gen_fit_norm', 'lig_gen_fit_variance', 'lig_gen_fit_L2_loss', 'lig_gen_fit_L1_loss', 'lig_n_atoms', 'lig_radius', 'lig_fit_n_atoms', 'lig_fit_radius', 'lig_fit_type_diff', 'lig_fit_exact_types', 'lig_fit_RMSD', 'lig_fit_time', 'lig_fit_n_visited', 'lig_est_type_diff', 'lig_est_exact_types', 'lig_gen_fit_n_atoms', 'lig_gen_fit_radius', 'lig_gen_fit_type_diff', 'lig_gen_fit_exact_types', 'lig_gen_fit_RMSD', 'lig_gen_fit_time', 'lig_gen_fit_n_visited', 'lig_gen_est_type_diff', 'lig_gen_est_exact_types', 'lig_n_frags', 'lig_error', 'lig_valid', 'lig_MW', 'lig_logP', 'lig_QED', 'lig_SAS', 'lig_NPS', 'lig_SMILES', 'lig_E', 'lig_min_E', 'lig_dE_min', 'lig_min_error', 'lig_min_time', 'lig_RMSD_min', 'lig_add_n_frags', 'lig_add_error', 'lig_add_valid', 'lig_add_MW', 'lig_add_logP', 'lig_add_QED', 'lig_add_SAS', 'lig_add_NPS', 'lig_add_SMILES', 'lig_add_SMILES_match', 'lig_add_ob_sim', 'lig_add_morgan_sim', 'lig_add_rdkit_sim', 'lig_add_maccs_sim', 'lig_add_E', 'lig_add_min_E', 'lig_add_dE_min', 'lig_add_min_error', 'lig_add_min_time', 'lig_add_RMSD_min', 'lig_add_dE_ref', 'lig_add_min_dE_ref', 'lig_add_RMSD_ref', 'lig_add_min_RMSD_ref', 'lig_fit_add_n_frags', 'lig_fit_add_error', 'lig_fit_add_valid', 'lig_fit_add_MW', 'lig_fit_add_logP', 'lig_fit_add_QED', 'lig_fit_add_SAS', 'lig_fit_add_NPS', 'lig_fit_add_SMILES', 'lig_fit_add_SMILES_match', 'lig_fit_add_ob_sim', 'lig_fit_add_morgan_sim', 'lig_fit_add_rdkit_sim', 'lig_fit_add_maccs_sim', 'lig_fit_add_E', 'lig_fit_add_min_E', 'lig_fit_add_dE_min', 'lig_fit_add_min_error', 'lig_fit_add_min_time', 'lig_fit_add_RMSD_min', 'lig_fit_add_dE_ref', 'lig_fit_add_min_dE_ref', 'lig_fit_add_RMSD_ref', 'lig_fit_add_min_RMSD_ref', 'lig_gen_fit_add_n_frags', 'lig_gen_fit_add_error', 'lig_gen_fit_add_valid', 'lig_gen_fit_add_MW', 'lig_gen_fit_add_logP', 'lig_gen_fit_add_QED', 'lig_gen_fit_add_SAS', 'lig_gen_fit_add_NPS', 'lig_gen_fit_add_SMILES', 'lig_gen_fit_add_SMILES_match', 'lig_gen_fit_add_ob_sim', 'lig_gen_fit_add_morgan_sim', 'lig_gen_fit_add_rdkit_sim', 'lig_gen_fit_add_maccs_sim', 'lig_gen_fit_add_E', 'lig_gen_fit_add_min_E', 'lig_gen_fit_add_dE_min', 'lig_gen_fit_add_min_error', 'lig_gen_fit_add_min_time', 'lig_gen_fit_add_RMSD_min', 'lig_gen_fit_add_dE_ref', 'lig_gen_fit_add_min_dE_ref', 'lig_gen_fit_add_RMSD_ref', 'lig_gen_fit_add_min_RMSD_ref']

# %% [markdown]
# Load RMSD calculations (between generated and minimised structures) for each ligand:

# %%
load_rmsd(dataroot, prefix, df)
# Out:
# Successfully reconstructed molecules: 92.97%

# %% [markdown]
# ### Molecules

# %%
# Add RDKit molecule
PandasTools.AddMoleculeColumnToFrame(df, f"{blob}_fit_add_SMILES", f"mol_{blob}")
# Out:
# RDKit ERROR: [15:03:11] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:11] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:11] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:11] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:11] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:11] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:11] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:11] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:11] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:11] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 8 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 11 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 12 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 8 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 10 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 8 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 8 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 29 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 8 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 26 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 11 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 29 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 27 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 C, 6, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 C, 6, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 29 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 28 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 8 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 26 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 26 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 8 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 12 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 28 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 12 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 27 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 12 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 C, 6, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 12 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 11 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 26 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 27 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 29 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 10 C, 6, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 12 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 29 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 26 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 29 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 2 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 26 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 11 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 26 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 12 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 26 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 26 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 C, 6, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 29 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 C, 6, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 12 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 2 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 30 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 24 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 25 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 22 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 23 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 26 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 11 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 10 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 8 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 3 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 10 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 11 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 2 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 10 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 26 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 11 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 10 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 2 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 3 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 11 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 3 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 12 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 3 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 10 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 12 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 17 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 8 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 26 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 10 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 15 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 10 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 8 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 10 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 3 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 2 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 8 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 16 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 19 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 13 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 7 Cl, 3, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 12 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 20 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 18 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 21 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 9 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# RDKit ERROR: [15:03:12] Explicit valence for atom # 8 Cl, 2, is greater than permitted

# %%
img = PandasTools.FrameToGridImage(
    df.drop_duplicates(subset=f"{blob}_fit_add_SMILES").sort_values(by=["lig_name",f"{blob}_fit_add_QED"], ascending=False).groupby("lig_name").head(6).reset_index(drop=True), 
    column=f"mol_{blob}", legendsCol=f"lig_name", molsPerRow=6, maxMols=60,
    returnPNG=False, # https://stackoverflow.com/questions/65470233/attributeerror-image-object-has-no-attribute-save
)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x2000 at 0x2AAAE527A050>

# %%
img.save(os.path.join("plots", prefix + "_topQED.png"))

# %% [markdown]
# ### Distributions

# %% [markdown]
# #### RMSD

# %%
sns.displot(df["rmsd"])
plt.savefig(os.path.join("plots", prefix + "_distRMSD.pdf"))
plt.savefig(os.path.join("plots", prefix + "_distRMSD.png"))

# %% [markdown]
# Systems with 0.0 RMSD are systems for which the minimisation failed (the generated molecule is not minimied but the minimised output is nonetheless produced). Some failures are due to "Unrecognized charge state for atoms: #X" while other are not better specified `UFF Exception` problems.

# %% [markdown]
# #### QED

# %%
sns.displot(df[f"{blob}_fit_add_QED"])
plt.savefig(os.path.join("plots", prefix + "_distQED.pdf"))
plt.savefig(os.path.join("plots", prefix + "_distQED.png"))

# %% [markdown]
# ### Simple Statistics

# %%
rmsd_statistics(df, maxRMSD)
# Out:
# Average RMSD: 1.4404813789394428
# Median RMSD: 1.461
# Percentage of low-RMSD samples: 16.36011616650532%

# %% [markdown]
# ### Correlation

# %%
to_plot = [f"{blob}_fit_add_QED", f"{blob}_fit_add_morgan_sim", "rmsd"]

g = sns.PairGrid(df[to_plot], corner=True)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
plt.savefig(os.path.join("plots", prefix + "_correlations.pdf"))
plt.savefig(os.path.join("plots", prefix + "_correlations.png"))

# %% [markdown]
# ### Filter Molecules

# %%
df_filtered = filter(df, maxRMSD, minQED)

# %%
img = PandasTools.FrameToGridImage(
    df_filtered, 
    column=f"mol_{blob}", legendsCol="lig_name", molsPerRow=6, maxMols=np.inf,
    returnPNG=False, # https://stackoverflow.com/questions/65470233/attributeerror-image-object-has-no-attribute-save
)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x3800 at 0x2AAAE795BC90>

# %%
img.save(os.path.join("plots", prefix + "_molfiltered.png"))

# %%
len(df_filtered)
# Out:
# 114

# %% [markdown]
# ## Variability Factor: 1.0

# %% [markdown]
# ### Data

# %%
datafile = "generated/BRD4_vf1.0_big.gen_metrics"

# %%
dataroot, prefix = root_and_prefix(datafile)
prefix
# Out:
# 'BRD4_vf1.0_big'

# %%
df = pd.read_csv(datafile, sep=" ")
df.head()
# Out:
#        lig_name  sample_idx   lig_norm  lig_variance  lig_gen_norm  \
# 0  ligand-1_min           0  32.281212           NaN     32.338009
# 1  ligand-1_min           1  32.281212           NaN     32.746601
# 2  ligand-1_min           2  32.281212           NaN     32.677238
# 3  ligand-1_min           3  32.281212           NaN     32.869080
# 4  ligand-1_min           4  32.281212           NaN     32.927082
#
#    lig_gen_variance  lig_gen_L2_loss  lig_gen_L1_loss  lig_latent_norm  \
# 0               NaN        19.493015       682.232483        29.897814
# 1               NaN        21.411243       703.766724        30.031115
# 2               NaN        16.367361       665.923462        30.309299
# 3               NaN        20.553886       703.242432        31.375877
# 4               NaN        18.654919       688.956848        31.345463
#
#    lig_latent_variance  ...  lig_gen_fit_add_E  lig_gen_fit_add_min_E  \
# 0                  NaN  ...       4.008805e+07              26.643160
# 1                  NaN  ...       3.354808e+04             494.920029
# 2                  NaN  ...       6.889199e+03              52.115185
# 3                  NaN  ...       1.627076e+04              36.506074
# 4                  NaN  ...       1.805847e+04              56.844166
#
#    lig_gen_fit_add_dE_min  lig_gen_fit_add_min_error  \
# 0           -4.008803e+07                        NaN
# 1           -3.305316e+04                        NaN
# 2           -6.837084e+03                        NaN
# 3           -1.623425e+04                        NaN
# 4           -1.800162e+04                        NaN
#
#    lig_gen_fit_add_min_time  lig_gen_fit_add_RMSD_min  lig_gen_fit_add_dE_ref  \
# 0                  0.029767                  1.331600            4.008798e+07
# 1                  0.015337                  0.994772            3.347449e+04
# 2                  0.010258                  0.784217            6.815609e+03
# 3                  0.023646                  1.383904            1.619717e+04
# 4                  0.008542                  0.436529            1.798488e+04
#
#    lig_gen_fit_add_min_dE_ref  lig_gen_fit_add_RMSD_ref  \
# 0                  -46.947277                       NaN
# 1                  421.329591                       NaN
# 2                  -21.475253                       NaN
# 3                  -37.084364                       NaN
# 4                  -16.746272                       NaN
#
#    lig_gen_fit_add_min_RMSD_ref
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 125 columns]

# %% [markdown]
# Load RMSD calculations (between generated and minimised structures) for each ligand:

# %%
load_rmsd(dataroot, prefix, df)
# Out:
# Successfully reconstructed molecules: 84.67%

# %%
df[df.rmsd > 10][["lig_name", "sample_idx", "rmsd"]]
# Out:
# Empty DataFrame
# Columns: [lig_name, sample_idx, rmsd]
# Index: []

# %% [markdown]
# ### Distributions

# %% [markdown]
# #### RMSD

# %%
sns.displot(df["rmsd"])
plt.savefig(os.path.join("plots", prefix + "_distRMSD.pdf"))
plt.savefig(os.path.join("plots", prefix + "_distRMSD.png"))

# %% [markdown]
# #### QED

# %%
sns.displot(df[f"{blob}_fit_add_QED"])
plt.savefig(os.path.join("plots", prefix + "_distQED.pdf"))
plt.savefig(os.path.join("plots", prefix + "_distQED.png"))

# %% [markdown]
# ### Simple Statistics

# %%
rmsd_statistics(df, maxRMSD)
# Out:
# Average RMSD: 1.4723327731191687
# Median RMSD: 1.44305
# Percentage of low-RMSD samples: 24.518719735443486%

# %% [markdown]
# ### Correlation

# %%
to_plot = [f"{blob}_fit_add_QED", f"{blob}_fit_add_morgan_sim", "rmsd"]

g = sns.PairGrid(df[to_plot], corner=True)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
plt.savefig(os.path.join("plots", prefix + "_correlations.pdf"))
plt.savefig(os.path.join("plots", prefix + "_correlations.png"))

# %% [markdown]
# ### Filter Molecules

# %%
df_filtered = filter(df, maxRMSD, minQED)

# %%
img = PandasTools.FrameToGridImage(
    df_filtered, 
    column=f"mol_{blob}", legendsCol="lig_name", molsPerRow=6, maxMols=np.inf,
    returnPNG=False, # https://stackoverflow.com/questions/65470233/attributeerror-image-object-has-no-attribute-save
)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x11000 at 0x2AAAE74274D0>

# %%
img.save(os.path.join("plots", prefix + "_molfiltered.png"))

# %%
len(df_filtered)
# Out:
# 326

# %% [markdown]
# ## Variability Factor: 5.0

# %% [markdown]
# ### Data

# %%
datafile = "generated/BRD4_vf5.0_big.gen_metrics"

# %%
dataroot, prefix = root_and_prefix(datafile)
prefix
# Out:
# 'BRD4_vf5.0_big'

# %%
df = pd.read_csv(datafile, sep=" ")
df.head()
# Out:
#        lig_name  sample_idx   lig_norm  lig_variance  lig_gen_norm  \
# 0  ligand-1_min           0  32.281212           NaN     37.641598
# 1  ligand-1_min           1  32.281212           NaN     35.332359
# 2  ligand-1_min           2  32.281212           NaN     33.581665
# 3  ligand-1_min           3  32.281212           NaN     37.569435
# 4  ligand-1_min           4  32.281212           NaN     41.190033
#
#    lig_gen_variance  lig_gen_L2_loss  lig_gen_L1_loss  lig_latent_norm  \
# 0               NaN       722.398682      4055.318604       126.732613
# 1               NaN       558.240295      3762.905029       125.742905
# 2               NaN       647.583313      4149.455078       133.260605
# 3               NaN       722.736877      4034.791260       126.446281
# 4               NaN       650.432983      4271.284668       137.476212
#
#    lig_latent_variance  ...  lig_gen_fit_add_E  lig_gen_fit_add_min_E  \
# 0                  NaN  ...       5.917633e+06             912.489470
# 1                  NaN  ...       7.946078e+06             645.089725
# 2                  NaN  ...       1.528455e+11             421.203405
# 3                  NaN  ...       5.459074e+04            1344.564010
# 4                  NaN  ...       1.513293e+08             677.027233
#
#    lig_gen_fit_add_dE_min  lig_gen_fit_add_min_error  \
# 0           -5.916720e+06                        NaN
# 1           -7.945433e+06                        NaN
# 2           -1.528455e+11                        NaN
# 3           -5.324617e+04                        NaN
# 4           -1.513286e+08                        NaN
#
#    lig_gen_fit_add_min_time  lig_gen_fit_add_RMSD_min  lig_gen_fit_add_dE_ref  \
# 0                  0.040111                  2.308581            5.917559e+06
# 1                  0.030249                  1.283953            7.946004e+06
# 2                  0.040413                  1.488381            1.528455e+11
# 3                  0.034479                  2.168368            5.451714e+04
# 4                  0.054132                  1.503658            1.513292e+08
#
#    lig_gen_fit_add_min_dE_ref  lig_gen_fit_add_RMSD_ref  \
# 0                  838.899032                       NaN
# 1                  571.499287                       NaN
# 2                  347.612968                       NaN
# 3                 1270.973573                       NaN
# 4                  603.436795                       NaN
#
#    lig_gen_fit_add_min_RMSD_ref
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 125 columns]

# %% [markdown]
# Load RMSD calculations (between generated and minimised structures) for each ligand:

# %%
load_rmsd(dataroot, prefix, df)
# Out:
# Successfully reconstructed molecules: 94.41%

# %%
df[df.rmsd > 10][["lig_name", "sample_idx", "rmsd"]]
# Out:
#            lig_name  sample_idx       rmsd
# 698    ligand-1_min         698   10.17207
# 1528   ligand-2_min         528   11.18033
# 5198   ligand-6_min         198   11.86101
# 5671   ligand-6_min         671   14.41347
# 5717   ligand-6_min         717   15.27835
# 7570   ligand-8_min         570   24.48685
# 9969  ligand-10_min         969  205.15136

# %% [markdown]
# Remove system with RMSD higer than 10:

# %%
df.drop(df[df.rmsd > 10].index, inplace=True)

# %% [markdown]
# ### Distributions

# %% [markdown]
# #### RMSD

# %%
sns.displot(df["rmsd"])
plt.savefig(os.path.join("plots", prefix + "_distRMSD.pdf"))
plt.savefig(os.path.join("plots", prefix + "_distRMSD.png"))

# %% [markdown]
# #### QED

# %%
sns.displot(df[f"{blob}_fit_add_QED"])
plt.savefig(os.path.join("plots", prefix + "_distQED.pdf"))
plt.savefig(os.path.join("plots", prefix + "_distQED.png"))

# %% [markdown]
# ### Simple Statistics

# %%
rmsd_statistics(df, maxRMSD)
# Out:
# Average RMSD: 1.7719888128047485
# Median RMSD: 1.7886549999999999
# Percentage of low-RMSD samples: 1.2189951240195038%

# %% [markdown]
# ### Correlation

# %%
to_plot = [f"{blob}_fit_add_QED", f"{blob}_fit_add_morgan_sim", "rmsd"]

g = sns.PairGrid(df[to_plot], corner=True)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
plt.savefig(os.path.join("plots", prefix + "_correlations.pdf"))
plt.savefig(os.path.join("plots", prefix + "_correlations.png"))

# %% [markdown]
# ### Filter Molecules

# %%
df_filtered = filter(df, maxRMSD, minQED)

# %%
img = PandasTools.FrameToGridImage(
    df_filtered, 
    column=f"mol_{blob}", legendsCol="lig_name", molsPerRow=6, maxMols=np.inf,
    returnPNG=False, # https://stackoverflow.com/questions/65470233/attributeerror-image-object-has-no-attribute-save
)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x400 at 0x2AAAE741CE10>

# %%
img.save(os.path.join("plots", prefix + "_molfiltered.png"))

# %%
len(df_filtered)
# Out:
# 12

# %% [markdown]
# ### All Molecules

# %%
# Add RDKit molecule
PandasTools.AddMoleculeColumnToFrame(df,f"{blob}_fit_add_SMILES", f"mol_{blob}")

# %%
img = PandasTools.FrameToGridImage(
    df.iloc[0:100], 
    column=f"mol_{blob}", legendsCol="lig_name", molsPerRow=6, maxMols=np.inf,
    returnPNG=False, # https://stackoverflow.com/questions/65470233/attributeerror-image-object-has-no-attribute-save
)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x3400 at 0x2AAAE7F9B0D0>
